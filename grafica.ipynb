# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.1)
y = np.sin(x)

plt.plot(x, y)
plt.grid()
plt.title('Gráfico de función Seno(x)')
plt.xlabel('Tiempo(s)')
plt.ylabel('Amplitud (cm)')
plt.show()
